# %% [markdown]
# # <center>Computer Vision - Input/Output + Basic operations</center>

# %% [markdown]
# In this first practical session, you will use the `opencv` library.

# %% [markdown]
# Import the libraries

# %%
# %matplotlib inline

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import ImageOps, ImageEnhance, Image
from augmentation import RandAugmentation

# %%
vid = cv2.VideoCapture(0)

FPS = vid.get(cv2.CAP_PROP_FPS)

VIDEO_LENGTH = 10 # in second

frame_w = int(vid.get(3))
frame_h = int(vid.get(4))

# %%
ret, frame = vid.read()

vid.release()

rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_frame)

plt.show()

# %%
hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
plt.imshow(hsv_frame)

plt.show()

# %%
pil_frame = Image.fromarray(rgb_frame)
contrast = ImageEnhance.Contrast(pil_frame).enhance(2)

contrast = np.array(contrast)
plt.imshow(contrast)
plt.show()

# %%
augmentation = RandAugmentation()

img, augment = augmentation(pil_frame)

print(augment)
img = np.array(img)
plt.subplot(1,2,1).set_title('Original')
plt.imshow(rgb_frame)
plt.subplot(1,2,2).set_title(augment['method'] + " - " + str(augment['value']))
plt.imshow(img)
plt.show()
# Out:
# {'method': 'mirror', 'value': 0}
